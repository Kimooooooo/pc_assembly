# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\82107\Desktop\4일 프로젝트 코드\pc_assembly\원시데이터\case.csv')
df
# Out:
#                                              제품명       가격  \
# 0                           DAVEN AQUA Lite (블랙)   19,320
# 1                         마이크로닉스 WIZMAX 우드리안 MAX   85,700
# 2     싸이번 LIMPID SC-M5 PLUS BONITO Edition (화이트)   53,000
# 3                         앱코 U30P 마린+ 디스플레이 (블랙)   53,000
# 4                            darkFlash DS500 RGB   39,000
# ...                                          ...      ...
# 1323                           EVERCOOL HDB-252A    4,000
# 1324               Phanteks VERTICAL GPU KIT 4.0  106,000
# 1325                              Phanteks XT V3   가격비교예정
# 1326                        몬스타 가츠 S620 RGB 강화유리   38,000
# 1327    라이트컴 COMS PCI Express 연장 아답터 16X (SP965)   23,640
#
#                               제조사      제품 분류  Unnamed: 4 지원보드규격 M-ATX M-ITX  \
# 0         DAVEN ( 제조사 웹사이트 바로가기 )  M-ATX 케이스         NaN   정보없음     ○     ○
# 1        마이크로닉스 ( 제조사 웹사이트 바로가기 )    ATX 케이스         NaN   정보없음     ○   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1328 entries, 0 to 1327
# Data columns (total 83 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   제품명             1328 non-null   object
#  1   가격              1328 non-null   object
#  2   제조사             1325 non-null   object
#  3   제품 분류           1299 non-null   object
#  4   Unnamed: 4      0 non-null      float64
#  5   지원보드규격          922 non-null    object
#  6   M-ATX           912 non-null    object
#  7   M-ITX           641 non-null    object
#  8   VGA 길이          1035 non-null   object
#  9   CPU쿨러 높이        1038 non-null   object
#  10  케이스 크기          1072 non-null   object
#  11  파워포함여부          1059 non-null   object
#  12  지원파워규격          882 non-null    object
#  13  내부 확장           1150 non-null   object
#  14  8.9cm베이         1071 non-null   object
#  15  6.4cm베이         882 non-null    object
#  16  저장장치 장착         927 non-null    object
# ...

# %%
df['제조사'] = df['제조사'].str.replace(r'\( 제조사 웹사이트 바로가기 \)','',regex=True)
df = df.drop(['지원보드규격','후면커넥터 방식','내부 확장','[패널]','[쿨러/튜닝]','외부포트','[크기]','[호환성]','LED 튜닝','컨트롤러 지원','Unnamed: 4','[변경사항]','KC인증','[부가기능]'],axis=1)
#필요없는내용제거
df = df.drop(['리모컨','카드리더기'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1328 entries, 0 to 1327
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   제품명             1328 non-null   object
#  1   가격              1328 non-null   object
#  2   제조사             1325 non-null   object
#  3   제품 분류           1299 non-null   object
#  4   M-ATX           912 non-null    object
#  5   M-ITX           641 non-null    object
#  6   VGA 길이          1035 non-null   object
#  7   CPU쿨러 높이        1038 non-null   object
#  8   케이스 크기          1072 non-null   object
#  9   파워포함여부          1059 non-null   object
#  10  지원파워규격          882 non-null    object
#  11  8.9cm베이         1071 non-null   object
#  12  6.4cm베이         882 non-null    object
#  13  저장장치 장착         927 non-null    object
#  14  PCI 슬롯(수평)      1013 non-null   object
#  15  전면 패널 타입        712 non-null    object
#  16  측면 패널 타입        948 non-null    object
# ...

# %%
df.to_csv('case.csv')
# Out:
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
