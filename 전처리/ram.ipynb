# %%
import pandas as pd 

df = pd.read_csv(r'C:\Users\82107\Desktop\4일 프로젝트 코드\pc_assembly\가공데이터\ram.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        840 non-null    int64
#  1   제품명               840 non-null    object
#  2   가격                840 non-null    object
#  3   제조사               840 non-null    object
#  4   사용 장치             840 non-null    object
#  5   제품 분류             840 non-null    object
#  6   메모리 규격            840 non-null    object
#  7   메모리 용량            840 non-null    object
#  8   동작클럭(대역폭)         840 non-null    object
#  9   램타이밍              840 non-null    object
#  10  동작전압              840 non-null    object
#  11  램개수               840 non-null    object
#  12  XMP3.0            840 non-null    object
#  13  온다이ECC            840 non-null    object
#  14  히트싱크              840 non-null    object
#  15  높이                840 non-null    object
# ...

# %%
df.drop(['부가기능','KC인증','Unnamed: 21','KC인증'],axis=1)
#노트북용 , 서버용 제거 
df = df[df['사용 장치'] == '데스크탑용'] 
df
# Out:
#                                                    제품명       가격  \
# 0                GeIL DDR5-5600 CL46 PRISTINE V (16GB)   84,990
# 1    ADATA DDR5-6000 CL30 LANCER BLADE RGB 화이트 패키지 ...  230,990
# 2    GeIL DDR5-6000 CL38 ORION V RGB White 패키지 (32G...     일시품절
# 3    마이크론 Crucial DDR5-5600 CL46 PRO 패키지 대원씨티에스 (32...  201,000
# 4                  ESSENCORE KLEVV DDR5-5600 CL46 파인인포  172,000
# ..                                                 ...      ...
# 834                            EKMEMORY DDR3-1333 인디핑크   39,300
# 835                                삼성전자 DDR3-1333 병행수입   11,800
# 836                                CYNEX DDR3-1333 엠트란   26,150
# 837                                 CYNEX DDR3-1066 멜론   24,000
# 838                                CYNEX DDR3-1066 엠트란   26,000
#
#                              제조사  사용 장치 제품 분류       메모리 규격 메모리 용량  \
# 0         GeIL ( 제조사 웹사이트 바로가기 )  데스크탑용  DDR5  DIMM(UDIMM)   16GB
# ...

# %%
df['사용 장치'].unique()
# Out:
# array(['데스크탑용'], dtype=object)
