# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import time

# 🔧 제외할 상세정보 항목
EXCLUDE_KEYS = {"유통회사", "등록년월", "안전확인인증", "적합성평가인증"}

# -----------------------------------------------------------------------------
# 브라우저 초기화
# -----------------------------------------------------------------------------
def init_driver(headless=True):
    options = webdriver.ChromeOptions()
    if headless:
        options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_argument("--lang=ko-KR")

    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)
    driver.set_window_size(1400, 1000)
    return driver

# -----------------------------------------------------------------------------
# 1️⃣ 기본 리스트 페이지에서 제품명/가격/pcode 추출
# -----------------------------------------------------------------------------
def get_basic_info_from_page(soup):
    products = []
    items = soup.select(".prod_item")

    for item in items:
        try:
            title_elem = item.select_one(".prod_name a")
            title = title_elem.get_text(strip=True) if title_elem else "N/A"

            # 가격
            price_elem = item.select_one(".price_sect strong") or item.select_one(".price_sect em")
            price = price_elem.get_text(strip=True) if price_elem else "N/A"

            # 제품 코드(pcode)
            pcode = None
            if title_elem and "href" in title_elem.attrs:
                href = title_elem["href"]
                if "pcode=" in href:
                    pcode = href.split("pcode=")[1].split("&")[0]

            if title != "N/A" and pcode:
                products.append({"제품명": title, "가격": price, "pcode": pcode})

        except Exception as e:
            print(f"⚠️ 항목 스킵: {e}")
            continue

    return products

# -----------------------------------------------------------------------------
# 2️⃣ 상세페이지에서 스펙 추출 (특정 항목 제외)
# -----------------------------------------------------------------------------
def get_detail_info(driver, pcode):
    try:
        detail_url = f'https://prod.danawa.com/info/?pcode={pcode}'
        driver.get(detail_url)
        time.sleep(3)

        soup = BeautifulSoup(driver.page_source, 'html.parser')
        specs = {}
        manufacturer = 'N/A'

        # ✅ 모든 spec 영역 탐색 (spec_tbl, prod_spec 둘 다 대응)
        tables = soup.select('.spec_tbl, .prod_spec')

        for table in tables:
            rows = table.select('tr')
            for row in rows:
                th_elems = row.select('th')
                td_elems = row.select('td')

                # ✅ th만 있고 td가 없는 경우도 있음 → 처리
                if th_elems and not td_elems:
                    for th in th_elems:
                        key = th.get_text(strip=True)
                        specs[key] = '정보없음'
                    continue

                # ✅ 일반적인 th–td 매칭
                for th, td in zip(th_elems, td_elems):
                    key = th.get_text(strip=True)
                    value = td.get_text(" ", strip=True)
                    specs[key] = value

        # ✅ 제외할 항목 필터링
        exclude_keys = {'등록년월', '유통회사', '안전확인인증', '적합성평가인증'}
        specs = {k: v for k, v in specs.items() if k not in exclude_keys}

        # ✅ 제조회사 별도 추출
        if '제조회사' in specs:
            manufacturer = specs.pop('제조회사')

        return manufacturer, specs

    except Exception as e:
        print(f"    ⚠️ 상세 페이지 에러: {e}")
        return 'N/A', {}


# -----------------------------------------------------------------------------
# 3️⃣ 페이지 이동 (1~10 → 다음 → 11~20 ...)
# -----------------------------------------------------------------------------
def click_next_page(driver, current_page):
    try:
        next_page = current_page + 1
        xpath = f'//a[@onclick="javascript:movePage({next_page}); return false;"]'
        next_btn = driver.find_element(By.XPATH, xpath)
        driver.execute_script("arguments[0].click();", next_btn)
        time.sleep(3)
        return True

    except NoSuchElementException:
        try:
            # 10페이지 단위로 다음 그룹 이동
            next_block = driver.find_element(By.XPATH, '//a[@class="btn_num btn_next"]')
            driver.execute_script("arguments[0].click();", next_block)
            time.sleep(3)
            return True
        except NoSuchElementException:
            print(f"✅ 마지막 페이지 도달")
            return False
    except Exception as e:
        print(f"⚠️ 페이지 이동 실패: {e}")
        return False

# -----------------------------------------------------------------------------
# 4️⃣ 모든 페이지 순회하며 기본 정보 수집
# -----------------------------------------------------------------------------
def crawl_all_pages(driver, base_url, max_products=99999):
    all_products = []
    page = 1

    url = base_url + "&sort=12"
    driver.get(url)
    time.sleep(4)

    while len(all_products) < max_products:
        print(f"\n📄 페이지 {page} 크롤링 중...")

        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)

        soup = BeautifulSoup(driver.page_source, "html.parser")
        page_products = get_basic_info_from_page(soup)

        if not page_products:
            print("✅ 더 이상 상품 없음")
            break

        print(f"✅ {len(page_products)}개 상품 발견")
        all_products.extend(page_products)

        if not click_next_page(driver, page):
            break

        page += 1

    return all_products

# -----------------------------------------------------------------------------
# 5️⃣ 상세 정보 병합
# -----------------------------------------------------------------------------
def add_detail_info(driver, products):
    print(f"\n{'='*70}")
    print("STEP 2: 상세 정보 크롤링")
    print(f"{'='*70}\n")
    
    total = len(products)
    
    for i, product in enumerate(products, 1):
        try:
            print(f"\n[{i}/{total}] {product['제품명'][:50]}...")

            if product['pcode']:
                manufacturer, specs = get_detail_info(driver, product['pcode'])
                product['제조사'] = manufacturer
                product['상세정보'] = str(specs)

                if specs:
                    preview = list(specs.items())[:2]
                    for k, v in preview:
                        print(f"   - {k}: {v[:40]}...")

                time.sleep(2)
            else:
                product['제조사'] = 'N/A'
                product['상세정보'] = '{}'

        except Exception as e:
            print(f"    ❌ 에러: {e}")
            product['제조사'] = 'N/A'
            product['상세정보'] = '{}'

        # ✅ 10개 단위로 중간 저장
        if i % 10 == 0:
            temp_df = pd.DataFrame(products[:i])
            temp_df = temp_df[['제품명', '가격', '제조사', '상세정보']]
            temp_df.to_csv('중간저장.csv', index=False, encoding='utf-8-sig')
            print(f"\n  📁 중간 저장 완료: {i}개 수집됨 (cpu_partial.csv)")

        if i % 10 == 0:
            print(f"\n  📊 진행률: {i}/{total} ({i/total*100:.1f}%)")

    return products

# -----------------------------------------------------------------------------
# 6️⃣ 실행 메인
# -----------------------------------------------------------------------------
def main():
    print("=" * 70)
    print(" 크롤링 시작")
    print("=" * 70)

    driver = init_driver(headless=False)  # 디버깅 시 False 추천

    try:
        base_url = "https://prod.danawa.com/list/?cate=112777"

        # 1단계: 목록 크롤링
        products = crawl_all_pages(driver, base_url, max_products=99999)
        print(f"\n✅ 기본 정보 {len(products)}개 수집 완료")

        # 2단계: 상세정보 추가
        products = add_detail_info(driver, products)

        # 3단계: 저장
        for p in products:
            p.pop("pcode", None)

        df = pd.DataFrame(products)
        df["상세정보"] = df["상세정보"].apply(lambda x: str(x))

        filename = "power_data_all.csv"
        df.to_csv(filename, index=False, encoding="utf-8-sig")

        print(f"\n✅ CSV 저장 완료: {filename}")
        print(f"총 {len(df)}개 상품")

    except Exception as e:
        print(f"❌ 오류 발생: {e}")
        import traceback
        traceback.print_exc()
    finally:
        driver.quit()
        print("\n크롤링 종료 ✅")

# -----------------------------------------------------------------------------
if __name__ == "__main__":
    main()
# Out:
# ======================================================================
#  크롤링 시작
# ======================================================================
#
# 📄 페이지 1 크롤링 중...
# ✅ 36개 상품 발견
#
# 📄 페이지 2 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지
블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [406/1156] 쿨러마스터 V SFX Gold 850 ATX3.1...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 850W...
#
# [407/1156] be quiet DARK POWER PRO 13 1600W 80PLUS티타늄...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1600W...
#
# [408/1156] AONE STORM 800K 80PLUS브론즈 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [409/1156] Antec CSK 550W DC 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 550W...
#
# [410/1156] NEWZEN SKULL 750XM 풀모듈러 ATX3.1 80PLUS골드 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
#   📁 중간 저장 완료: 410개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 410/1156 (35.5%)
#
# [411/1156] AONE STORM 700K 80PLUS브론즈 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [412/1156] NEWZEN SKULL 750XM 풀모듈러 ATX3.1 80PLUS골드 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [413/1156] 이엠텍 레드빗 CRPS-2000W-1U 80PLUS플래티넘...
#    - 제품 분류: 서버용 파워...
#    - 정격출력: 2000W...
#
# [414/1156] 3RSYS AK 600S 80PLUS스탠다드 230V EU...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [415/1156] MONTECH TITAN PLA 1200W 플래티넘 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [416/1156] GIGABYTE UD850GM PG5 80PLUS골드 풀모듈러 화이트 피씨디렉트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [417/1156] 잘만 Wattbit II 500W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [418/1156] DEEPCOOL GAMER STORM PF750L 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [419/1156] 마이크로닉스 WIZMAX 750W 80PLUS실버 ATX3.0...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [420/1156] 3RSYS AK 500S 80PLUS스탠다드 230V EU...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
#   📁 중간 저장 완료: 420개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 420/1156 (36.3%)
#
# [421/1156] NEWZEN SKULL 850EM 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [422/1156] DEEPCOOL PX1200G 80PLUS골드 풀모듈러 ATX3.0...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [423/1156] MONTECH TITAN PLA 1000W 플래티넘 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [424/1156] 맥스엘리트 MAXWELL COUNT 850W 80PLUS골드 풀모듈러 (본체+플랫멀티팩)...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [425/1156] 마이크로닉스 COOLMAX FOCUS II 700W ETA BRONZE PCIE5.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [426/1156] 잘만 Tager GAMING 500W 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [427/1156] COX SECURE SC-600N...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [428/1156] AONE STORM 600W 80PLUS브론즈 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [429/1156] 쿨러마스터 G800 GOLD...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [430/1156] 앱코 XPERT XP-700N...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
#   📁 중간 저장 완료: 430개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 430/1156 (37.2%)
#
# [431/1156] 쿨러마스터 M2000 80PLUS플래티넘 230V 풀모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 2000W...
#
# [432/1156] EVGA 750 GQ 80PLUS골드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [433/1156] AONE Micro 450P 벌크...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 200W...
#
# [434/1156] ASUS ROG THOR 1000P2...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [435/1156] 마이크로닉스 ZERO PLUS 600W Active PFC...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [436/1156] 마이크로닉스 ASTRO PLATINUM 1050W 풀모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1050W...
#
# [437/1156] 쿨러마스터 GOLD V750 V2 화이트 풀모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [438/1156] AONE STORM 700W 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [439/1156] Antec SIGNATURE 1000W TITANIUM...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [440/1156] AONE STORM 500W 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
#   📁 중간 저장 완료: 440개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 440/1156 (38.1%)
#
# [441/1156] FSP FSP500-50FDB...
#    - 제품 분류: Flex-ATX 파워...
#    - 정격출력: 500W...
#
# [442/1156] AONE 500S KC (벌크)...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 200W...
#
# [443/1156] COUGAR GLE 1200 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [444/1156] 쿨러마스터 MWE Gold 1050 V2 풀모듈러 ATX3.0 SF6 Blanka...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1050W...
#
# [445/1156] AcBEL R1CA2801A 800W 80PLUS플래티넘...
#    - 제품 분류: 서버용 파워...
#    - 정격출력: 800W...
#
# [446/1156] GIGABYTE UD1000GM PG5 V2 ICE 80PLUS골드 풀모듈러 ATX3.1 ...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [447/1156] 마이크로닉스 ZERO POWER 500W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [448/1156] 마이크로닉스 ZERO PLUS 500W Active PFC...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [449/1156] AONE TFX-500P KC...
#    - 제품 분류: TFX 파워...
#    - 정격출력: 250W...
#
# [450/1156] AONE 600T KC...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 300W...
#
#   📁 중간 저장 완료: 450개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 450/1156 (38.9%)
#
# [451/1156] 마이크로닉스 Performance II PV RGB Sync 600W 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [452/1156] COUGAR GEX PRO 850 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [453/1156] AONE TFX-450P KC...
#    - 제품 분류: TFX 파워...
#    - 정격출력: 200W...
#
# [454/1156] 마이크로닉스 MTFX400STE08S 벌크...
#    - 제품 분류: TFX 파워...
#    - 정격출력: 400W...
#
# [455/1156] AONE MICRO 500P KC...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 230W...
#
# [456/1156] AONE 태왕 EP600L KC...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 230W...
#
# [457/1156] GIGABYTE UD850GM PG5 V2 ICE 80PLUS골드 풀모듈러 ATX3.1 피...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [458/1156] 잘만 TeraMax II 1200W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [459/1156] AONE STORM 600LF 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [460/1156] AONE STORM 500LF...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
#   📁 중간 저장 완료: 460개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 460/1156 (39.8%)
#
# [461/1156] FSP FSP300-60GHS(85)...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 300W...
#
# [462/1156] 잘만 TeraMax II 850W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [463/1156] FSP FSP350-50FFB...
#    - 제품 분류: 서버용 파워...
#    - 정격출력: 350W...
#
# [464/1156] AONE STORM 500LF 더블포워드 V2.3...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [465/1156] FSP FSP1200-50ADB 80PLUS골드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [466/1156] AONE STORM 600LF...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [467/1156] AONE 500P KC...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 230W...
#
# [468/1156] 쿨러마스터 GOLD V750 V2 블랙 풀모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [469/1156] AONE Micro 450P-KC...
# ...
#
# [978/1156] 한국이스트 EA901RM...
#    - 제품 분류: UPS...
#    - : ...
#
# [979/1156] 에너지옵티머스 EOP-1800...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1800W...
#
# [980/1156] 델타 UPS Agilon VX-1000VA...
#    - 제품 분류: UPS...
#    - : ...
#
#   📁 중간 저장 완료: 980개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 980/1156 (84.8%)
#
# [981/1156] 에너맥스 Platimax EPM1700EGT...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1700W...
#
# [982/1156] FSP HYPER K 600W 80PLUS스탠다드 230V EU 중고...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [983/1156] 스카이디지탈 파워스테이션5 PS5-850SV 80PLUS실버...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [984/1156] AcBEL CE2 450...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 400W...
#
# [985/1156] 이도디스플레이 ICE-MAN 500L V2.2 벌크...
#    - 제품 분류: ATX 파워...
#    - 케이블연결: 케이블일체형...
#
# [986/1156] REX COOL SILENT HS1-600 NEW...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 300W...
#
# [987/1156] 한국이스트 EA902...
#    - 제품 분류: UPS...
#    - : ...
#
# [988/1156] EATON 5P 850GR1U...
#    - 제품 분류: UPS...
#    - : ...
#
# [989/1156] NZXT C1000 Gold Core 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [990/1156] FSP HYPER K 500W 80PLUS스탠다드 230V EU 중고...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
#   📁 중간 저장 완료: 990개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 990/1156 (85.6%)
#
# [991/1156] KSTAR PRO2050...
#    - 제품 분류: UPS...
#    - : ...
#
# [992/1156] 셀텍 LR1204 DC to DC 150W 어댑터 미포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [993/1156] topower Guardian TOP-900DG 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 900W...
#
# [994/1156] 셀텍 LR1108 160W Plug Type 파워어댑터 미포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 160W...
#
# [995/1156] 한국이스트 EA903RM...
#    - 제품 분류: UPS...
#    - : ...
#
# [996/1156] 델타 R-1K...
#    - 제품 분류: UPS...
#    - : ...
#
# [997/1156] 포게임 PROMASTER PRO 700 BRONZE...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [998/1156] 써멀테이크 터프파워 그랜드 RGB 650W GOLD 풀모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [999/1156] 셀텍 LR1108 160W Plug Type 60W 파워어댑터 포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 160W...
#
# [1000/1156] KSTAR HP910C (RM)...
#    - 제품 분류: UPS...
#    - : ...
#
#   📁 중간 저장 완료: 1000개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1000/1156 (86.5%)
#
# [1001/1156] 셀텍 LR1010 DC to DC 180W 19V/9.5A 180W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1002/1156] 에너지옵티머스 EXCEL CLASSIC 700W 80PLUS브론즈 230V EU 풀모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [1003/1156] 스카이디지탈 파워스테이션5 PS5-500N...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [1004/1156] ANIX TFX-500AX...
#    - 제품 분류: TFX 파워...
#    - 정격출력: 200W...
#
# [1005/1156] 셀텍 LR1010 DC to DC 200W 어댑터 미포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 200W...
#
# [1006/1156] CORSAIR iCUE CX650F RGB 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [1007/1156] 셀텍 LR1010 DC to DC 180W 어댑터 미포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1008/1156] 셀텍 LR1204 DC to DC 120W 12V/5A 60W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1009/1156] 셀텍 LR1204 DC to DC 120W 어댑터 미포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1010/1156] BITFENIX BPAB 700W 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
#   📁 중간 저장 완료: 1010개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1010/1156 (87.4%)
#
# [1011/1156] PNC PARTNER EVEREST 600K RGB 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1012/1156] PNC PARTNER EVEREST 500W PLUS 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [1013/1156] 피닉스CNS 듀얼파워커넥터 ADD2PSU...
#    - 제품 분류: 전용 액세서리...
#    - : ...
#
# [1014/1156] 셀텍 LR1108 150W Plug Type 파워어댑터 미포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 150W...
#
# [1015/1156] NZXT C850 Gold Core 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [1016/1156] 셀텍 LR1108 160W Plug Type 120W 파워어댑터 포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 160W...
#
# [1017/1156] 셀텍 LR1010 DC to DC 200W 19V/9.5A 180W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 200W...
#
# [1018/1156] BITFENIX BPAB 800W 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W\...
#
# [1019/1156] 르그랑코리아 KEOR SP2000...
#    - 제품 분류: UPS...
#    - : ...
#
# [1020/1156] 앱코 ABKONCORE TN 850W GOLD 풀모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
#   📁 중간 저장 완료: 1020개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1020/1156 (88.2%)
#
# [1021/1156] 마이크로닉스 COOLMAX FOCUS 600W 80Plus 230V EU 중고...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1022/1156] 비콘즈 SPACE SP-700W 80PLUS스탠다드 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [1023/1156] EATON Ellipse ECO 650 DIN 기본...
#    - 제품 분류: UPS...
#    - : ...
#
# [1024/1156] 셀텍 LR1108 160W Plug Type 102W 파워어댑터 포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 160W...
#
# [1025/1156] 셀텍 LR1010 DC to DC 200W 19.5V/4.62A 90W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 200W...
#
# [1026/1156] 셀텍 LR1204 DC to DC 150W 12V/12.5A 150W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1027/1156] 에너맥스 MARBLEBRON EMB750EWT 80PLUS브론즈 모듈러...
#    - 제품 분류: 서버용 파워...
#    - 정격출력: 750W...
#
# [1028/1156] 앱코 SUITMASTER AXE 600W (중고)...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1029/1156] Antec NeoECO NE650C 80PLUS브론즈 중고...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [1030/1156] 썬루트 TX1800 80PLUS브론즈 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1800W...
#
#   📁 중간 저장 완료: 1030개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1030/1156 (89.1%)
#
# [1031/1156] CORSAIR CV750 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [1032/1156] ABB코리아 UPS PowerValue 11T G2 2 kVA B...
#    - 제품 분류: UPS...
#    - : ...
#
# [1033/1156] 에너지옵티머스 Thunderbolt S600 PRO...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 230W...
#
# [1034/1156] NZXT C750 Gold Core 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [1035/1156] EVGA SUPERNOVA 650 GA 80PLUS골드 해외구매...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [1036/1156] 마이크로닉스 Cyclone III 600W After Cooling 중고...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1037/1156] 잘만 EcoMax 600W 중고...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1038/1156] FSP FSP500-50HPN (중고)...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [1039/1156] 스카이디지탈 파워스테이션5 PS5-800BR 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [1040/1156] topower Guardian TOP-700DG Single Rail 80PLUS브론즈 화...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
#   📁 중간 저장 완료: 1040개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1040/1156 (90.0%)
#
# [1041/1156] BABEL Sense 500PB V2.3 Blackbel Series...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 230W...
#
# [1042/1156] APC SRT5KRMXLI...
#    - 제품 분류: UPS...
#    - : ...
#
# [1043/1156] KSTAR HP930C...
#    - 제품 분류: UPS...
#    - : ...
#
# [1044/1156] 에너맥스 MARBLEBRON EMB650AWT 80PLUS브론즈 모듈러...
#    - 제품 분류: 서버용 파워...
#    - 정격출력: 650W...
#
# [1045/1156] 써멀테이크 터프파워 GF3 1650W GOLD 풀모듈러 ATX3.0...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1650W...
#
# [1046/1156] 델타 R-3K...
#    - 제품 분류: UPS...
#    - : ...
#
# [1047/1156] TAGER JN600W GAMING...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1048/1156] 삼성전자 PSD-350DHGB (중고)...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 350W...
#
# [1049/1156] 르그랑코리아 KEOR SP1500...
#    - 제품 분류: UPS...
#    - : ...
#
# [1050/1156] PNC PARTNER EVEREST 1600AP...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1600W...
#
#   📁 중간 저장 완료: 1050개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1050/1156 (90.8%)
#
# [1051/1156] APC SRT10KRMXLI...
#    - 제품 분류: UPS...
#    - : ...
#
# [1052/1156] WEED W600-ORIGIN REAL...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1053/1156] EATON 5PX 1500i RT2U...
#    - 제품 분류: UPS...
#    - : ...
#
# [1054/1156] PNC PARTNER EVEREST 900W ATX3.0 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 900W...
#
# [1055/1156] ASUS TUF Gaming 750W GOLD...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [1056/1156] 잘만 MegaMax 600W 80PLUS스탠다드 중고...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1057/1156] PNC PARTNER EVEREST 500K RGB 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [1058/1156] 쿨러마스터 V1000...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W 이상...
#
# [1059/1156] 잘만 MegaMax 700W 80PLUS스탠다드 중고...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [1060/1156] 시소닉 SSP-500ES2 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
#   📁 중간 저장 완료: 1060개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1060/1156 (91.7%)
#
# [1061/1156] ABB코리아 UPS PowerValue 11T G2 1 kVA B...
#    - 제품 분류: UPS...
#    - : ...
#
# [1062/1156] ABB코리아 UPS PowerValue 11 RT 1kVA B...
#    - 제품 분류: UPS...
#    - : ...
#
# [1063/1156] 써멀테이크 터프파워 iRGB PLUS 1200W PLATINUM...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [1064/1156] BABEL ECO 620BK V2.3 Blackbel Series...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 280W...
#
# [1065/1156] 에너맥스 Platimax D.F. EPF1050EWT 80PLUS플래티넘 풀모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1050W...
#
# [1066/1156] 델타 N-3K...
#    - 제품 분류: UPS...
#    - : ...
#
# [1067/1156] 셀텍 LR1108 150W Plug Type 60W 파워어댑터 포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 150W...
#
# [1068/1156] GSI DOHICH VT-500 PLUS...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 230W...
#
# [1069/1156] ASUS ROG STRIX 850G 화이트 에디션 80PLUS골드 인텍앤컴퍼니...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [1070/1156] Antec VP500P PLUS 80PLUS스탠다드 230V EU (중고)...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
#   📁 중간 저장 완료: 1070개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1070/1156 (92.6%)
#
# [1071/1156] ABB코리아 UPS PowerValue 11RT G2 10 kVA...
#    - 제품 분류: UPS...
#    - : ...
#
# [1072/1156] 델타 N-2K...
#    - 제품 분류: UPS...
#    - : ...
#
# [1073/1156] GSI DOHICH TFX-450...
#    - 제품 분류: TFX 파워...
#    - 정격출력: 200W...
#
# [1074/1156] PCM UPS BLACK KNIGHT BNT-1000AP...
#    - 제품 분류: UPS...
#    - : ...
#
# [1075/1156] 에너지옵티머스 EXCEL FOCUS 1000W 80PLUS골드 풀모듈러 ATX3.0...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [1076/1156] 썬루트 Mining 1800W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1800W...
#
# [1077/1156] CORSAIR CX750 NEW 80PLUS브론즈 중고...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [1078/1156] ABB코리아 UPS PowerValue 11T G2 3 kVA B...
#    - 제품 분류: UPS...
#    - : ...
#
# [1079/1156] APC SRT3000RMXLI...
#    - 제품 분류: UPS...
#    - : ...
#
# [1080/1156] APC SRT96RMBP 외장 배터리...
#    - 제품 분류: UPS...
#    - : ...
#
#   📁 중간 저장 완료: 1080개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1080/1156 (93.4%)
#
# [1081/1156] APC SRT6KRMXLI...
#    - 제품 분류: UPS...
#    - : ...
#
# [1082/1156] 써멀테이크 터프파워 그랜드 RGB 750W 골드 풀모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [1083/1156] 델타 N-1K...
#    - 제품 분류: UPS...
#    - : ...
#
# [1084/1156] 셀텍 LR1108 150W Plug Type 102W 파워어댑터 포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 150W...
#
# [1085/1156] PCM UPS KIN-1500AP...
#    - 제품 분류: UPS...
#    - : ...
#
# [1086/1156] PCM UPS KIN-1000AP...
#    - 제품 분류: UPS...
#    - : ...
#
# [1087/1156] 포게임 ECOMASTER ECO 750 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [1088/1156] 델타 RT-5K...
#    - 제품 분류: UPS...
#    - : ...
#
# [1089/1156] 써멀테이크 터프파워 GF3 1200W GOLD 풀모듈러 ATX3.0...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [1090/1156] 에너지옵티머스 EXCEL FOCUS 1000W 80PLUS골드 풀모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
#   📁 중간 저장 완료: 1090개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1090/1156 (94.3%)
#
# [1091/1156] ATEN OL3000HV...
#    - 제품 분류: UPS...
#    - : ...
#
# [1092/1156] 셀텍 LR1010 DC to DC 180W 24V/5A 120W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1093/1156] 셀텍 LR1108 160W Plug Type 150W 파워어댑터 포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 160W...
#
# [1094/1156] 셀텍 LR1010 DC to DC 200W 19V/6.32A 120W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 200W...
#
# [1095/1156] 한국이스트 EA902RM...
#    - 제품 분류: UPS...
#    - : ...
#
# [1096/1156] EATON 5A1200I-DIN-K...
#    - 제품 분류: UPS...
#    - : ...
#
# [1097/1156] 르그랑코리아 KEOR SP1000...
#    - 제품 분류: UPS...
#    - : ...
#
# [1098/1156] APC SRV10KRI...
#    - 제품 분류: UPS...
#    - : ...
#
# [1099/1156] APC SRV2KRI...
#    - 제품 분류: UPS...
#    - : ...
#
# [1100/1156] MSI MAG A550BNL 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 550W...
#
#   📁 중간 저장 완료: 1100개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1100/1156 (95.2%)
#
# [1101/1156] PNC PARTNER EVEREST 1600AP PCIE5...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1600W...
#
# [1102/1156] 셀텍 LR1010 DC to DC 180W 19V/6.32A 120W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1103/1156] 셀텍 LR1204 DC to DC 150W 12V/10A 120W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1104/1156] 셀텍 LR1204 DC to DC 150W 12V/8.5A 102W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1105/1156] 셀텍 LR1204 DC to DC 150W 12V/5A 60W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1106/1156] 델타 R-2K...
#    - 제품 분류: UPS...
#    - : ...
#
# [1107/1156] TAGER JN600W GAMING 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1108/1156] 에너지옵티머스 EXCEL CLASSIC 600W 80PLUS브론즈 230V EU...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1109/1156] 한국이스트 EA903...
#    - 제품 분류: UPS...
#    - : ...
#
# [1110/1156] 한국이스트 EA901...
#    - 제품 분류: UPS...
#    - : ...
#
#   📁 중간 저장 완료: 1110개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1110/1156 (96.0%)
#
# [1111/1156] PNC PARTNER EVEREST 750W 화이트 80PLUS스탠다드 230V EU 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [1112/1156] ATEN OL2000HV...
#    - 제품 분류: UPS...
#    - : ...
#
# [1113/1156] ATEN OL1500HV...
#    - 제품 분류: UPS...
#    - : ...
#
# [1114/1156] ATEN OL1000HV...
#    - 제품 분류: UPS...
#    - : ...
#
# [1115/1156] PNC PARTNER EVEREST 650W 80PLUS스탠다드 230V EU 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [1116/1156] BABEL BM-600VP PFC Double Forward Silverbel Series...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1117/1156] AONE 태왕 EP600 KC 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 300W...
#
# [1118/1156] AONE 태왕 EP600L KC 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 230W...
#
# [1119/1156] ANIX 듀얼파워 커넥터...
#    - 제품 분류: 전용 액세서리...
#    - : ...
#
# [1120/1156] 셀텍 LR1108 150W Plug Type 120W 파워어댑터 포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 150W...
#
#   📁 중간 저장 완료: 1120개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1120/1156 (96.9%)
#
# [1121/1156] 셀텍 LR1204 DC to DC 120W 12V/10A 120W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1122/1156] 르그랑코리아 DK Plus5000...
#    - 제품 분류: UPS...
#    - : ...
#
# [1123/1156] PNC PARTNER EVEREST 750W 80PLUS스탠다드 230V EU...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [1124/1156] PNC PARTNER EVEREST 600K RGB 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [1125/1156] ABB코리아 UPS PowerValue 11T G2 10 kVA B...
#    - 제품 분류: UPS...
#    - : ...
#
# [1126/1156] ABB코리아 UPS PowerValue 11T G2 6 kVA B...
#    - 제품 분류: UPS...
#    - : ...
#
# [1127/1156] ABB코리아 UPS PowerValue 11RT G2 6 kVA...
#    - 제품 분류: UPS...
#    - : ...
#
# [1128/1156] ABB코리아 UPS PowerValue 11 RT 3kVA B...
#    - 제품 분류: UPS...
#    - : ...
#
# [1129/1156] ABB코리아 UPS PowerValue 11 RT 2kVA B...
#    - 제품 분류: UPS...
#    - : ...
#
# [1130/1156] 에너지옵티머스 EXCEL 500W 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
#   📁 중간 저장 완료: 1130개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1130/1156 (97.8%)
#
# [1131/1156] BABEL Sense 600ST V2.3 Blackbel Series...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 250W...
#
# [1132/1156] BABEL Sense 600PB V2.3 Blackbel Series...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 250W...
#
# [1133/1156] 셀텍 LR1010 DC to DC 180W 19V/5.5A 105W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1134/1156] 셀텍 LR1010 DC to DC 180W 19V/4.74A 90W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1135/1156] 르그랑코리아 NIKY S1000...
#    - 제품 분류: UPS...
#    - : ...
#
# [1136/1156] 르그랑코리아 NIKY S1500...
#    - 제품 분류: UPS...
#    - : ...
#
# [1137/1156] APC SRT192RMBP 외장 배터리...
#    - 제품 분류: UPS...
#    - : ...
#
# [1138/1156] APC SRT8KRMXLI...
#    - 제품 분류: UPS...
#    - : ...
#
# [1139/1156] APC SRT2200RMXLI...
#    - 제품 분류: UPS...
#    - : ...
#
# [1140/1156] APC SRT72RMBP 외장 배터리...
#    - 제품 분류: UPS...
#    - : ...
#
#   📁 중간 저장 완료: 1140개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1140/1156 (98.6%)
#
# [1141/1156] 르그랑코리아 NIKY S3000...
#    - 제품 분류: UPS...
#    - : ...
#
# [1142/1156] 라이트컴 COMS 릴레이형 듀얼파워 커넥터 IE870...
#    - 제품 분류: 전용 액세서리...
#    - : ...
#
# [1143/1156] NCTOP DC-DC GM-120 SH...
#    - 제품 분류: DC to DC...
#    - 정격출력: 120W...
#
# [1144/1156] EATON 5P 1550GR1U...
#    - 제품 분류: UPS...
#    - : ...
#
# [1145/1156] 이도디스플레이 ICE-MAN 600TI V2.3 KC 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 400W...
#
# [1146/1156] Bestone SK-II 500SA V2...
#    - 제품 분류: ATX 파워...
#    - 케이블연결: 케이블일체형...
#
# [1147/1156] Bestone SK-II 450TFX V2 벌크...
#    - 제품 분류: TFX 파워...
#    - 케이블연결: 케이블일체형...
#
# [1148/1156] ares Akira 600AK Plus UP...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 230W...
#
# [1149/1156] 셀텍 LR1108 150W Plug Type 72W 파워어댑터 포함...
#    - 제품 분류: DC to DC...
#    - 정격출력: 150W...
#
# [1150/1156] APC SURT1000RMXLI...
#    - 제품 분류: UPS...
#    - : ...
#
#   📁 중간 저장 완료: 1150개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 1150/1156 (99.5%)
#
# [1151/1156] APC RBC106 교체용 배터리...
#    - 제품 분류: UPS...
#    - : ...
#
# [1152/1156] APC RBC22 교체용 배터리...
#    - 제품 분류: UPS...
#    - : ...
#
# [1153/1156] APC RBC23 교체용 배터리...
#    - 제품 분류: UPS...
#    - : ...
#
# [1154/1156] BABEL ECO 620BK V2.3 Blackbel Series 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 280W...
#
# [1155/1156] 셀텍 LR1010 DC to DC 180W 24V/7A 168W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# [1156/1156] 셀텍 LR1204 DC to DC 120W 12V/8.5A 102W 어댑터 포함...
#    - 제품 분류: DC to DC...
#    - : ...
#
# ✅ CSV 저장 완료: power_data_all.csv
# 총 1156개 상품
#
# 크롤링 종료 ✅

# %%
import pandas as pd 
df = pd.read_csv('cpu.csv')

df
# Out:
#                                       제품명       가격                 제조사  \
# 0     AMD 라이젠7-5세대 7800X3D (라파엘) (멀티팩 정품)  453,640  AMD(제조사 웹사이트 바로가기)
# 1      인텔 코어 울트라5 시리즈2 245K (애로우레이크) (정품)  320,910   인텔(제조사 웹사이트 바로가기)
# 2      인텔 코어 울트라7 시리즈2 265K (애로우레이크) (정품)  449,530   인텔(제조사 웹사이트 바로가기)
# 3    AMD 라이젠5-6세대 9600 (그래니트 릿지) (멀티팩 정품)  275,930  AMD(제조사 웹사이트 바로가기)
# 4                AMD 라이젠5-5세대 7500F (라파엘)  185,470  AMD(제조사 웹사이트 바로가기)
# ..                                    ...      ...                 ...
# 547                   인텔 펜티엄 E5300 (울프데일)      940              인텔 펜티엄
# 548                 인텔 코어2듀오 E8500 (울프데일)    4,700            인텔 코어2듀오
# 549                 인텔 셀러론 G1630 (아이비브릿지)    2,200              인텔 셀러론
# 550                     인텔 펜티엄 E2200 (콘로)    5,400              인텔 펜티엄
# 551                   인텔 코어2듀오 E4500 (콘로)    8,010            인텔 코어2듀오
#
#                                                   상세정보  \
# 0    {'AMD CPU종류': '라이젠7-5세대', '코어 수': '8코어', '메모리 ...
# 1    {'인텔 CPU종류': '코어 울트라5(S2)', '코어 수': 'P6+E8코어',...
# 2    {'인텔 CPU종류': '코어 울트라7(S2)', '코어 수': 'P8+E12코어'...
# 3    {'AMD CPU종류': '라이젠5-6세대', '코어 수': '6코어', '메모리 ...
# 4    {'AMD CPU종류': '라이젠5-5세대', '코어 수': '6코어', '메모리 ...
# ..                                                 ...
# 547  {'인텔 CPU종류': '인텔(펜티엄)', '코어 수': '듀얼 코어', '내장그래...
# 548  {'인텔 CPU종류': '인텔(코어2듀오)', '코어 수': '듀얼 코어', '내장...
# 549  {'인텔 CPU종류': '인텔(셀러론)', '코어 수': '듀얼 코어', '메모리 ...
# 550  {'인텔 CPU종류': '인텔(펜티엄)', '코어 수': '듀얼 코어', '내장그래...
# 551  {'인텔 CPU종류': '인텔(코어2듀오)', '코어 수': '듀얼 코어', '내장...
#
#                                                    텍스트
# 0    AMD 라이젠7-5세대 7800X3D (라파엘) (멀티팩 정품) 453,640 AM...
# 1    인텔 코어 울트라5 시리즈2 245K (애로우레이크) (정품) 320,910 인텔(...
# 2    인텔 코어 울트라7 시리즈2 265K (애로우레이크) (정품) 449,530 인텔(...
# 3    AMD 라이젠5-6세대 9600 (그래니트 릿지) (멀티팩 정품) 275,930 A...
# 4    AMD 라이젠5-5세대 7500F (라파엘) 185,470 AMD(제조사 웹사이트 ...
# ..                                                 ...
# 547  인텔 펜티엄 E5300 (울프데일) 940 인텔 펜티엄 인텔 CPU종류 인텔(펜티엄...
# 548  인텔 코어2듀오 E8500 (울프데일) 4,700 인텔 코어2듀오 인텔 CPU종류 ...
# 549  인텔 셀러론 G1630 (아이비브릿지) 2,200 인텔 셀러론 인텔 CPU종류 인텔...
# 550  인텔 펜티엄 E2200 (콘로) 5,400 인텔 펜티엄 인텔 CPU종류 인텔(펜티엄...
# 551  인텔 코어2듀오 E4500 (콘로) 8,010 인텔 코어2듀오 인텔 CPU종류 인텔...
#
# [552 rows x 5 columns]

# %%
import pandas as pd
import ast

df = pd.read_csv('sdd_data_all.csv', encoding='utf-8-sig')

def create_embedding_text(row):
    specs = ast.literal_eval(row['상세정보'])
    spec_text = " ".join([f"{k} {v}" for k, v in specs.items()])
    return f"{row['제품명']} {row['가격']} {row['제조사']} {spec_text}"

df['텍스트'] = df.apply(create_embedding_text, axis=1)
df.to_csv('sdd.csv', index=False, encoding='utf-8-sig')

# %%
import pandas as pd 

df = pd.read_csv(r'C:\Users\PCN\Desktop\pcn\가공데이터\ssd.csv')
df = df.drop('상세정보',axis=1)
df.to_csv(r'C:\Users\PCN\Desktop\pcn\가공데이터\ssd.csv')

# %%
df = df.drop('상세정보',axis=1)
df
# Out:
#                                       제품명       가격                 제조사  \
# 0     AMD 라이젠7-5세대 7800X3D (라파엘) (멀티팩 정품)  453,640  AMD(제조사 웹사이트 바로가기)
# 1      인텔 코어 울트라5 시리즈2 245K (애로우레이크) (정품)  320,910   인텔(제조사 웹사이트 바로가기)
# 2      인텔 코어 울트라7 시리즈2 265K (애로우레이크) (정품)  449,530   인텔(제조사 웹사이트 바로가기)
# 3    AMD 라이젠5-6세대 9600 (그래니트 릿지) (멀티팩 정품)  275,930  AMD(제조사 웹사이트 바로가기)
# 4                AMD 라이젠5-5세대 7500F (라파엘)  185,470  AMD(제조사 웹사이트 바로가기)
# ..                                    ...      ...                 ...
# 547                   인텔 펜티엄 E5300 (울프데일)      940              인텔 펜티엄
# 548                 인텔 코어2듀오 E8500 (울프데일)    4,700            인텔 코어2듀오
# 549                 인텔 셀러론 G1630 (아이비브릿지)    2,200              인텔 셀러론
# 550                     인텔 펜티엄 E2200 (콘로)    5,400              인텔 펜티엄
# 551                   인텔 코어2듀오 E4500 (콘로)    8,010            인텔 코어2듀오
#
#                                                    텍스트
# 0    AMD 라이젠7-5세대 7800X3D (라파엘) (멀티팩 정품) 453,640 AM...
# 1    인텔 코어 울트라5 시리즈2 245K (애로우레이크) (정품) 320,910 인텔(...
# 2    인텔 코어 울트라7 시리즈2 265K (애로우레이크) (정품) 449,530 인텔(...
# 3    AMD 라이젠5-6세대 9600 (그래니트 릿지) (멀티팩 정품) 275,930 A...
# 4    AMD 라이젠5-5세대 7500F (라파엘) 185,470 AMD(제조사 웹사이트 ...
# ..                                                 ...
# 547  인텔 펜티엄 E5300 (울프데일) 940 인텔 펜티엄 인텔 CPU종류 인텔(펜티엄...
# 548  인텔 코어2듀오 E8500 (울프데일) 4,700 인텔 코어2듀오 인텔 CPU종류 ...
# 549  인텔 셀러론 G1630 (아이비브릿지) 2,200 인텔 셀러론 인텔 CPU종류 인텔...
# 550  인텔 펜티엄 E2200 (콘로) 5,400 인텔 펜티엄 인텔 CPU종류 인텔(펜티엄...
# 551  인텔 코어2듀오 E4500 (콘로) 8,010 인텔 코어2듀오 인텔 CPU종류 인텔...
#
# [552 rows x 4 columns]
