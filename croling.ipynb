# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import time

# 🔧 제외할 상세정보 항목
EXCLUDE_KEYS = {"유통회사", "등록년월", "안전확인인증", "적합성평가인증"}

# -----------------------------------------------------------------------------
# 브라우저 초기화
# -----------------------------------------------------------------------------
def init_driver(headless=True):
    options = webdriver.ChromeOptions()
    if headless:
        options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_argument("--lang=ko-KR")

    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)
    driver.set_window_size(1400, 1000)
    return driver

# -----------------------------------------------------------------------------
# 1️⃣ 기본 리스트 페이지에서 제품명/가격/pcode 추출
# -----------------------------------------------------------------------------
def get_basic_info_from_page(soup):
    products = []
    items = soup.select(".prod_item")

    for item in items:
        try:
            title_elem = item.select_one(".prod_name a")
            title = title_elem.get_text(strip=True) if title_elem else "N/A"

            # 가격
            price_elem = item.select_one(".price_sect strong") or item.select_one(".price_sect em")
            price = price_elem.get_text(strip=True) if price_elem else "N/A"

            # 제품 코드(pcode)
            pcode = None
            if title_elem and "href" in title_elem.attrs:
                href = title_elem["href"]
                if "pcode=" in href:
                    pcode = href.split("pcode=")[1].split("&")[0]

            if title != "N/A" and pcode:
                products.append({"제품명": title, "가격": price, "pcode": pcode})

        except Exception as e:
            print(f"⚠️ 항목 스킵: {e}")
            continue

    return products

# -----------------------------------------------------------------------------
# 2️⃣ 상세페이지에서 스펙 추출 (특정 항목 제외)
# -----------------------------------------------------------------------------
def get_detail_info(driver, pcode):
    try:
        detail_url = f'https://prod.danawa.com/info/?pcode={pcode}'
        driver.get(detail_url)
        time.sleep(3)

        soup = BeautifulSoup(driver.page_source, 'html.parser')
        specs = {}
        manufacturer = 'N/A'

        # ✅ 모든 spec 영역 탐색 (spec_tbl, prod_spec 둘 다 대응)
        tables = soup.select('.spec_tbl, .prod_spec')

        for table in tables:
            rows = table.select('tr')
            for row in rows:
                th_elems = row.select('th')
                td_elems = row.select('td')

                # ✅ th만 있고 td가 없는 경우도 있음 → 처리
                if th_elems and not td_elems:
                    for th in th_elems:
                        key = th.get_text(strip=True)
                        specs[key] = '정보없음'
                    continue

                # ✅ 일반적인 th–td 매칭
                for th, td in zip(th_elems, td_elems):
                    key = th.get_text(strip=True)
                    value = td.get_text(" ", strip=True)
                    specs[key] = value

        # ✅ 제외할 항목 필터링
        exclude_keys = {'등록년월', '유통회사', '안전확인인증', '적합성평가인증'}
        specs = {k: v for k, v in specs.items() if k not in exclude_keys}

        # ✅ 제조회사 별도 추출
        if '제조회사' in specs:
            manufacturer = specs.pop('제조회사')

        return manufacturer, specs

    except Exception as e:
        print(f"    ⚠️ 상세 페이지 에러: {e}")
        return 'N/A', {}


# -----------------------------------------------------------------------------
# 3️⃣ 페이지 이동 (1~10 → 다음 → 11~20 ...)
# -----------------------------------------------------------------------------
def click_next_page(driver, current_page):
    try:
        next_page = current_page + 1
        xpath = f'//a[@onclick="javascript:movePage({next_page}); return false;"]'
        next_btn = driver.find_element(By.XPATH, xpath)
        driver.execute_script("arguments[0].click();", next_btn)
        time.sleep(3)
        return True

    except NoSuchElementException:
        try:
            # 10페이지 단위로 다음 그룹 이동
            next_block = driver.find_element(By.XPATH, '//a[@class="btn_num btn_next"]')
            driver.execute_script("arguments[0].click();", next_block)
            time.sleep(3)
            return True
        except NoSuchElementException:
            print(f"✅ 마지막 페이지 도달")
            return False
    except Exception as e:
        print(f"⚠️ 페이지 이동 실패: {e}")
        return False

# -----------------------------------------------------------------------------
# 4️⃣ 모든 페이지 순회하며 기본 정보 수집
# -----------------------------------------------------------------------------
def crawl_all_pages(driver, base_url, max_products=99999):
    all_products = []
    page = 1

    url = base_url + "&sort=12"
    driver.get(url)
    time.sleep(4)

    while len(all_products) < max_products:
        print(f"\n📄 페이지 {page} 크롤링 중...")

        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)

        soup = BeautifulSoup(driver.page_source, "html.parser")
        page_products = get_basic_info_from_page(soup)

        if not page_products:
            print("✅ 더 이상 상품 없음")
            break

        print(f"✅ {len(page_products)}개 상품 발견")
        all_products.extend(page_products)

        if not click_next_page(driver, page):
            break

        page += 1

    return all_products

# -----------------------------------------------------------------------------
# 5️⃣ 상세 정보 병합
# -----------------------------------------------------------------------------
def add_detail_info(driver, products):
    print(f"\n{'='*70}")
    print("STEP 2: 상세 정보 크롤링")
    print(f"{'='*70}\n")
    
    total = len(products)
    
    for i, product in enumerate(products, 1):
        try:
            print(f"\n[{i}/{total}] {product['제품명'][:50]}...")

            if product['pcode']:
                manufacturer, specs = get_detail_info(driver, product['pcode'])
                product['제조사'] = manufacturer
                product['상세정보'] = str(specs)

                if specs:
                    preview = list(specs.items())[:2]
                    for k, v in preview:
                        print(f"   - {k}: {v[:40]}...")

                time.sleep(2)
            else:
                product['제조사'] = 'N/A'
                product['상세정보'] = '{}'

        except Exception as e:
            print(f"    ❌ 에러: {e}")
            product['제조사'] = 'N/A'
            product['상세정보'] = '{}'

        # ✅ 10개 단위로 중간 저장
        if i % 10 == 0:
            temp_df = pd.DataFrame(products[:i])
            temp_df = temp_df[['제품명', '가격', '제조사', '상세정보']]
            temp_df.to_csv('중간저장.csv', index=False, encoding='utf-8-sig')
            print(f"\n  📁 중간 저장 완료: {i}개 수집됨 (cpu_partial.csv)")

        if i % 10 == 0:
            print(f"\n  📊 진행률: {i}/{total} ({i/total*100:.1f}%)")

    return products

# -----------------------------------------------------------------------------
# 6️⃣ 실행 메인
# -----------------------------------------------------------------------------
def main():
    print("=" * 70)
    print(" 크롤링 시작")
    print("=" * 70)

    driver = init_driver(headless=False)  # 디버깅 시 False 추천

    try:
        base_url = "https://prod.danawa.com/list/?cate=112777"

        # 1단계: 목록 크롤링
        products = crawl_all_pages(driver, base_url, max_products=99999)
        print(f"\n✅ 기본 정보 {len(products)}개 수집 완료")

        # 2단계: 상세정보 추가
        products = add_detail_info(driver, products)

        # 3단계: 저장
        for p in products:
            p.pop("pcode", None)

        df = pd.DataFrame(products)
        df["상세정보"] = df["상세정보"].apply(lambda x: str(x))

        filename = "power_data_all.csv"
        df.to_csv(filename, index=False, encoding="utf-8-sig")

        print(f"\n✅ CSV 저장 완료: {filename}")
        print(f"총 {len(df)}개 상품")

    except Exception as e:
        print(f"❌ 오류 발생: {e}")
        import traceback
        traceback.print_exc()
    finally:
        driver.quit()
        print("\n크롤링 종료 ✅")

# -----------------------------------------------------------------------------
if __name__ == "__main__":
    main()
# Out:
# ======================================================================
#  크롤링 시작
# ======================================================================
#
# 📄 페이지 1 크롤링 중...
# ✅ 36개 상품 발견
#
# 📄 페이지 2 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 3 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 4 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 5 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 6 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 7 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 8 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 9 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 10 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 11 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 12 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 13 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 14 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 15 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 16 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 17 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 18 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 19 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 20 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 21 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 22 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 23 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 24 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 25 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 26 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 27 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 28 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 29 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 30 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 31 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 32 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 33 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 34 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 35 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 36 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 37 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 38 크롤링 중...
# ✅ 30개 상품 발견
#
# 📄 페이지 39 크롤링 중...
# ✅ 10개 상품 발견
# ✅ 마지막 페이지 도달
#
# ✅ 기본 정보 1156개 수집 완료
#
# ======================================================================
# STEP 2: 상세 정보 크롤링
# ======================================================================
#
#
# [1/1156] 마이크로닉스 Classic II 풀체인지 700W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [2/1156] 쿨러마스터 MWE GOLD 850 V3 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [3/1156] darkFlash 퍼펙트모스트 850W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [4/1156] 마이크로닉스 WIZMAX G-1000W 80PLUS골드 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [5/1156] 마이크로닉스 Classic II 풀체인지 700W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [6/1156] darkFlash 퍼펙트모스트 850W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [7/1156] 마이크로닉스 Classic II 850W 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [8/1156] 잘만 GigaMax III 850W 80PLUS브론즈 모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [9/1156] 마이크로닉스 WIZMAX G-1000W 80PLUS골드 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [10/1156] MONTECH CENTURY II 1050 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1050W...
#
#   📁 중간 저장 완료: 10개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 10/1156 (0.9%)
#
# [11/1156] Segotep GM1250W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1250W...
#
# [12/1156] 시소닉 NEW FOCUS V4 GX-850 GOLD 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [13/1156] 마이크로닉스 Classic II 풀체인지 600W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [14/1156] 마이크로닉스 Classic II 풀체인지 500W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [15/1156] 마이크로닉스 Classic II 850W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [16/1156] SuperFlower SF-1200F14XP LEADEX VII PRO PLATINUM 블...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [17/1156] SuperFlower SF-1000F14GE LEADEX III GOLD UP ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [18/1156] 맥스엘리트 STARS CYGNUS 850W 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [19/1156] 마이크로닉스 Classic II 750W 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [20/1156] SuperFlower SF-850F14XG LEADEX VII GOLD ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
#   📁 중간 저장 완료: 20개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 20/1156 (1.7%)
#
# [21/1156] 잘만 EcoMax 500W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [22/1156] 마이크로닉스 Classic II 풀체인지 800W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [23/1156] 맥스엘리트 STARS GEMINI 750W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [24/1156] 마이크로닉스 Classic II 풀체인지 650W 80PLUS스탠다드 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [25/1156] SuperFlower SF-1200F14XP LEADEX VII PRO PLATINUM 화...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [26/1156] 앱코 SETTLER 하이브리드 PCIE5.1 STH-1000B ETA SILVER 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [27/1156] 시소닉 NEW FOCUS V4 GX-1000 GOLD 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [28/1156] FSP VITA GD 750W 80PLUS골드 ATX 3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [29/1156] 마이크로닉스 WIZMAX G-1200W 80PLUS골드 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [30/1156] 잘만 MegaMax 600W 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
#   📁 중간 저장 완료: 30개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 30/1156 (2.6%)
#
# [31/1156] MONTECH CENTURY II 1050 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1050W...
#
# [32/1156] 맥스엘리트 STARS GEMINI 850W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [33/1156] darkFlash 퍼펙트모스트 850W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [34/1156] 쿨러마스터 MWE GOLD 850 V3 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [35/1156] MONTECH CENTURY II 850 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [36/1156] 마이크로닉스 Classic II 1200W 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [37/1156] SuperFlower SF-850F14GE LEADEX III GOLD UP ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [38/1156] 잘만 MegaMax II 700W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [39/1156] 마이크로닉스 COOLMAX VISION II 500W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [40/1156] darkFlash 퍼펙트모스트 800W 80PLUS브론즈 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
#   📁 중간 저장 완료: 40개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 40/1156 (3.5%)
#
# [41/1156] SuperFlower SF-850F14XP LEADEX VII PRO PLATINUM 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [42/1156] 마이크로닉스 Classic II 풀체인지 800W 80PLUS브론즈 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [43/1156] 마이크로닉스 Classic II 1050W 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1050W...
#
# [44/1156] CORSAIR WS3000 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 3000W...
#
# [45/1156] 맥스엘리트 STARS GEMINI 650W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [46/1156] Antec GSK 850W V2 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [47/1156] 맥스엘리트 STARS GEMINI 750W 80PLUS브론즈 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [48/1156] CORSAIR RMx Series RM1000x ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [49/1156] 마이크로닉스 Classic II 풀체인지 700W 80PLUS브론즈 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [50/1156] Segotep GM1250W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1250W...
#
#   📁 중간 저장 완료: 50개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 50/1156 (4.3%)
#
# [51/1156] CORSAIR SF1000 ATX3.1...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 1000W...
#
# [52/1156] 시소닉 VERTEX GX-1200 GOLD 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [53/1156] MSI MEG Ai1600T 80PLUS티타늄 풀모듈러 ATX 3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1600W...
#
# [54/1156] 마이크로닉스 Classic II 풀체인지 600W 80PLUS실버 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [55/1156] AONE 시그니처 750W 80PLUS브론즈 풀모듈러 베이직 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [56/1156] 마이크로닉스 COOLMAX FOCUS II 500W ETA BRONZE...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [57/1156] 마이크로닉스 Classic II 1050W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1050W...
#
# [58/1156] MSI MAG A1000GL 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [59/1156] 맥스엘리트 STARS GEMINI 650W 80PLUS브론즈 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [60/1156] 에너지옵티머스 EXCEL II 500W 80PLUS스탠다드 230V EU 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
#   📁 중간 저장 완료: 60개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 60/1156 (5.2%)
#
# [61/1156] DEEPCOOL PL800D 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [62/1156] Antec CSK PRO 850W 80PLUS브론즈 230V EU 모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [63/1156] NEWZEN SKULL 850SM 모듈러 ATX3.1 80PLUS골드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [64/1156] darkFlash UPMOST 850W 80PLUS골드 풀모듈러 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [65/1156] CORSAIR SF750 80PLUS플래티넘...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 750W...
#
# [66/1156] SuperFlower SF-850F14XG LEADEX VII GOLD 화이트 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [67/1156] SuperFlower SF-750F14GE LEADEX III GOLD UP ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [68/1156] 마이크로닉스 Classic II 풀체인지 600W 80PLUS브론즈 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [69/1156] SuperFlower SF-1000F14XG LEADEX VII GOLD ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [70/1156] 마이크로닉스 Classic II 풀체인지 750W 80PLUS스탠다드 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
#   📁 중간 저장 완료: 70개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 70/1156 (6.1%)
#
# [71/1156] 마이크로닉스 Classic II 750W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [72/1156] 시소닉 NEW FOCUS V4 GX-1000 GOLD 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [73/1156] SuperFlower SF-1300F14XG LEADEX VII GOLD 화이트 ATX3....
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1300W...
#
# [74/1156] 시소닉 FOCUS GOLD GM-850 모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [75/1156] GIGABYTE UD850GM PG5 80PLUS골드 풀모듈러 ATX3.0 제이씨현...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [76/1156] 잘만 Wattbit II 400W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 400W...
#
# [77/1156] MSI MPG A850GS 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [78/1156] 리안리 EDGE GOLD 1200 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [79/1156] darkFlash 퍼펙트모스트 700W 80PLUS브론즈 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [80/1156] SuperFlower SF-850Z12DB Zillion DB ETA실버 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
#   📁 중간 저장 완료: 80개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 80/1156 (6.9%)
#
# [81/1156] 시소닉 NEW FOCUS V4 GX-750 GOLD 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [82/1156] 마이크로닉스 Classic II 1000W 80PLUS플래티넘 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [83/1156] 마이크로닉스 COOLMAX P-850W 80PLUS플래티넘 ATX3.0...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [84/1156] MSI MEG Ai1300P 80PLUS플래티넘 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1300W...
#
# [85/1156] 시소닉 NEW FOCUS V4 GX-850 GOLD 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [86/1156] 시소닉 VERTEX GX-1200 GOLD 풀모듈러 화이트 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [87/1156] AONE 시그니처 750W 80PLUS브론즈 풀모듈러 베이직 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [88/1156] 맥스엘리트 STARS CYGNUS 850W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [89/1156] FSP VITA GM 750W 80PLUS골드 ATX 3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [90/1156] SuperFlower SF-850F14XP LEADEX VII PRO PLATINUM 화이...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
#   📁 중간 저장 완료: 90개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 90/1156 (7.8%)
#
# [91/1156] 마이크로닉스 WIZMAX G-1650W 80PLUS골드 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1650W...
#
# [92/1156] 맥스엘리트 MAXWELL PRIMO 600W 80PLUS스탠다드 플랫...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [93/1156] Antec GSK 850W 화이트 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [94/1156] SuperFlower SF-750Z12DB Zillion DB ETA실버 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [95/1156] 쿨러마스터 V SFX Gold 850 ATX3.1 화이트...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 850W...
#
# [96/1156] FSP VITA GM 1000W 80PLUS골드 ATX 3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [97/1156] 잘만 EcoMax 700W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [98/1156] 마이크로닉스 COOLMAX VISION II 800W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [99/1156] 마이크로닉스 Classic II 풀체인지 800W 80PLUS실버 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [100/1156] 잘만 EcoMax 600W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
#   📁 중간 저장 완료: 100개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 100/1156 (8.7%)
#
# [101/1156] CORSAIR RM1000e ETA플래티넘 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [102/1156] darkFlash SAVEMOST 500W 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [103/1156] 앱코 코어맥스 CM-700B ETA브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [104/1156] CORSAIR RM1000e ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [105/1156] AONE STORM 500LF 더블포워드 V2.3 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [106/1156] CORSAIR CX Series CX650...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [107/1156] darkFlash 퍼펙트모스트 800W 80PLUS브론즈 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [108/1156] SuperFlower SF-600R12ST MEGA 80PLUS스탠다드 230V EU...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [109/1156] 마이크로닉스 COOLMAX ELITE II 500W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [110/1156] CORSAIR HX1200i 80PLUS플래티넘 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
#   📁 중간 저장 완료: 110개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 110/1156 (9.5%)
#
# [111/1156] AONE STORM 600W 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [112/1156] 맥스엘리트 MAXWELL PRIMO 700W 80PLUS스탠다드 플랫...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [113/1156] 리안리 SP750 80PLUS골드 블랙...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 750W...
#
# [114/1156] SuperFlower SF-1600F14HT LEADEX TITANIUM ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1600W...
#
# [115/1156] 현대파워 VEGA ST-500W 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [116/1156] 마이크로닉스 Compact TFX 400W 80Plus 230V EU...
#    - 제품 분류: TFX 파워...
#    - 정격출력: 400W...
#
# [117/1156] GIGABYTE P650G 80PLUS골드 피씨디렉트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [118/1156] 에너지옵티머스 Mach III 500K v2.3...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [119/1156] SuperFlower SF-1000F14XP LEADEX VII PRO PLATINUM 블...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [120/1156] 마이크로닉스 COOLMAX VISION II 600W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
#   📁 중간 저장 완료: 120개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 120/1156 (10.4%)
#
# [121/1156] 잘만 DecaMax 700W 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [122/1156] 맥스엘리트 MAXWELL PRIMO 500W 80PLUS스탠다드 플랫...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [123/1156] APC BX950MI-GR...
#    - 제품 분류: UPS...
#    - : ...
#
# [124/1156] 마이크로닉스 Classic II 풀체인지 900W 80PLUS실버 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 900W...
#
# [125/1156] 리안리 EDGE GOLD 1000 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [126/1156] darkFlash SAVEMOST 700W 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [127/1156] 마이크로닉스 WIZMAX G-850W 80PLUS골드 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [128/1156] SuperFlower SF-1000F14GE LEADEX III GOLD UP ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [129/1156] ASUS TUF Gaming 1000W GOLD...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [130/1156] SuperFlower SF-1300F14XG LEADEX VII GOLD ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1300W...
#
#   📁 중간 저장 완료: 130개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 130/1156 (11.2%)
#
# [131/1156] SuperFlower SF-1000F14XG LEADEX VII GOLD 화이트 ATX3....
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [132/1156] 리안리 SP750 80PLUS골드 화이트...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 750W...
#
# [133/1156] 마이크로닉스 WIZMAX 750W 80PLUS실버 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [134/1156] CORSAIR SF750 ATX3.1...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 750W...
#
# [135/1156] 시소닉 CORE V2 GX-750 GOLD 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [136/1156] darkFlash 퍼펙트모스트 750W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [137/1156] AONE STORM SFX 300LF...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 300W...
#
# [138/1156] Segotep BN850W KR 80PLUS브론즈 ATX 3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [139/1156] 마이크로닉스 Compact SFX 450W 80PLUS브론즈...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 450W...
#
# [140/1156] 마이크로닉스 COOLMAX FOCUS II 600W ETA BRONZE...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
#   📁 중간 저장 완료: 140개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 140/1156 (12.1%)
#
# [141/1156] 시소닉 CORE V2 GX-650 GOLD 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [142/1156] Segotep BN750W KR 80PLUS브론즈 ATX 3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [143/1156] AONE 시그니처 750W 80PLUS브론즈 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [144/1156] AONE 시그니처 850W 80PLUS브론즈 풀모듈러 베이직 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [145/1156] 마이크로닉스 COOLMAX ELITE II 600W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [146/1156] 마이크로닉스 Classic II 750W 80PLUS실버 모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [147/1156] 잘만 MegaMax ET 600W 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [148/1156] 마이크로닉스 Classic II 풀체인지 700W 80PLUS실버 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [149/1156] MSI MAG A650GLS 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [150/1156] ASUS ROG THOR 1600W Titanium III...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1600W...
#
#   📁 중간 저장 완료: 150개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 150/1156 (13.0%)
#
# [151/1156] 잘만 MegaMax II 800W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [152/1156] 잘만 GigaMax III 650W 80PLUS브론즈 모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [153/1156] 마이크로닉스 Classic II 풀체인지 550W 80PLUS스탠다드 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 550W...
#
# [154/1156] 마이크로닉스 Classic II 850W 80PLUS실버 모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [155/1156] 쿨러마스터 MWE 브론즈 750 V3 230V ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [156/1156] 맥스엘리트 STARS GEMINI 850W 80PLUS브론즈 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [157/1156] 쿨러마스터 MWE 브론즈 550 V3 230V ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 550W...
#
# [158/1156] 시소닉 CORE V2 GX-850 GOLD 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [159/1156] 마이크로닉스 Classic II 풀체인지 500W 80PLUS실버 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [160/1156] AONE STORM 800W 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
#   📁 중간 저장 완료: 160개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 160/1156 (13.8%)
#
# [161/1156] 마이크로닉스 Classic II 1300W 80PLUS플래티넘 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1300W...
#
# [162/1156] AONE STORM 750W 80PLUS브론즈 플랫...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [163/1156] 마이크로닉스 ASTRO II PT 850W 80PLUS플래티넘 풀모듈러 ATX3.0...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [164/1156] 쿨러마스터 MWE GOLD 650 V3 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [165/1156] 마이크로닉스 COOLMAX VISION II 700W...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [166/1156] 앱코 코어맥스 CM-500B ETA브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [167/1156] 잘만 ZM500W-XEII...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [168/1156] 마이크로닉스 ASTRO II PT 1000W 80PLUS플래티넘 풀모듈러 ATX3.0...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [169/1156] MSI MAG A650BN 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [170/1156] NEWZEN SKULL 750EM 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
#   📁 중간 저장 완료: 170개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 170/1156 (14.7%)
#
# [171/1156] 마이크로닉스 WIZMAX P-2500W 80PLUS플래티넘 ATX 3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 2500W...
#
# [172/1156] GIGABYTE P650SS 80PLUS실버 FDB ATX3.0 피씨디렉트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [173/1156] darkFlash SAVEMOST 600W 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [174/1156] FSP FlexGURU 250W...
#    - 제품 분류: Flex-ATX 파워...
#    - 정격출력: 250W...
#
# [175/1156] 엔티스 EG 1000W 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [176/1156] MSI MAG A650BNL 화이트 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [177/1156] 마이크로닉스 Classic II 750W 80PLUS브론즈 230V EU HDB 핑크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [178/1156] 시소닉 CORE V2 GX-750 GOLD 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [179/1156] 잘만 TeraMax II SE 1000W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [180/1156] 시소닉 PRIME PLATINUM PX-1600 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1600W...
#
#   📁 중간 저장 완료: 180개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 180/1156 (15.6%)
#
# [181/1156] Segotep GM1250W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1250W...
#
# [182/1156] 쿨러마스터 MWE GOLD 650 V3 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [183/1156] MSI MAG A850GLS 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [184/1156] GIGABYTE UD1000GM 80PLUS골드 풀모듈러 피씨디렉트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [185/1156] 마이크로닉스 COOLMAX P-1050W 80PLUS플래티넘 ATX3.0...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1050W...
#
# [186/1156] MSI MAG A600DN 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [187/1156] MSI MPG A1000G 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [188/1156] 마이크로닉스 Classic II 1200W 80PLUS골드 풀모듈러 화이트 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [189/1156] 마이크로닉스 CASLON M 850W 80PLUS실버 모듈러 ATX3.0...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [190/1156] 맥스엘리트 STARS CYGNUS 1000W 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
#   📁 중간 저장 완료: 190개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 190/1156 (16.4%)
#
# [191/1156] SuperFlower SF-1000F14XP LEADEX VII PRO PLATINUM 화...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [192/1156] 쿨러마스터 MWE 브론즈 650 V3 230V ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [193/1156] MSI MAG A1250GL 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1250W...
#
# [194/1156] CORSAIR CX Series CX750...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [195/1156] 시소닉 CORE V2 GX-850 GOLD 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [196/1156] 맥스엘리트 STARS CYGNUS 1000W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [197/1156] MSI MPG A850G 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [198/1156] Segotep GM850W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [199/1156] FSP VITA GD 850W 80PLUS골드 ATX 3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [200/1156] 마이크로닉스 Performance II PV 700W 80PLUS브론즈 FDB...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
#   📁 중간 저장 완료: 200개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 200/1156 (17.3%)
#
# [201/1156] AONE 시그니처 1000W 80PLUS브론즈 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [202/1156] 마이크로닉스 Performance II HV 1000W 80PLUS브론즈 FDB...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [203/1156] CORSAIR SF850 ATX3.1...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 850W...
#
# [204/1156] 마이크로닉스 Performance II HV 850W 80PLUS브론즈 FDB...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [205/1156] 마이크로닉스 Compact SFX 400W 80PLUS브론즈...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 400W...
#
# [206/1156] SuperFlower SF-2800F14HP LEADEX TITANIUM ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 2800W...
#
# [207/1156] 잘만 MegaMax II 600W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [208/1156] 맥스엘리트 STARS CYGNUS 1200W 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [209/1156] 마이크로닉스 Performance II PV 600W 80PLUS브론즈 FDB...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [210/1156] MSI MAG A750GL 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
#   📁 중간 저장 완료: 210개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 210/1156 (18.2%)
#
# [211/1156] 맥스엘리트 STARS CYGNUS 1200W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [212/1156] 마이크로닉스 Performance II PV 500W 80PLUS브론즈 FDB...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [213/1156] MSI MAG A850GL 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [214/1156] Segotep GM850W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [215/1156] 리안리 EDGE 1000 80PLUS플래티넘 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [216/1156] 쿨러마스터 MWE GOLD 750 V3 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [217/1156] 마이크로닉스 Classic II 650W 80PLUS브론즈 230V EU HDB 핑크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [218/1156] 리안리 EDGE GOLD 850 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [219/1156] darkFlash 퍼펙트모스트 700W 80PLUS브론즈 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [220/1156] NZXT C1000 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
#   📁 중간 저장 완료: 220개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 220/1156 (19.0%)
#
# [221/1156] 맥스엘리트 MAXWELL COUNT 850W 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [222/1156] 쿨러마스터 MWE 브론즈 650 V3 230V ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [223/1156] MSI MAG A750BN 80PLUS브론즈 PCIE5...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [224/1156] 잘만 MegaMax 800W 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [225/1156] Segotep GM1000W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [226/1156] 마이크로닉스 WIZMAX 850W 80PLUS실버 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [227/1156] Antec SF850X 80PLUS골드 SFX 풀모듈러 ATX3.1...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 850W...
#
# [228/1156] 시소닉 PRIME TITANIUM TX-1600 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1600W...
#
# [229/1156] CORSAIR RMx Series RM850x ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [230/1156] SilverStone HELA 2050R Platinum ATX3.1 마이크로닉스...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 2050W...
#
#   📁 중간 저장 완료: 230개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 230/1156 (19.9%)
#
# [231/1156] CORSAIR RM850x SHIFT 80PLUS골드 ATX3.0 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [232/1156] 맥스엘리트 MAXWELL DUKE 1000W 80PLUS플래티넘 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [233/1156] 마이크로닉스 COOLMAX FOCUS II 800W ETA BRONZE PCIE5.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 800W...
#
# [234/1156] 잘만 DecaMax 600W 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [235/1156] 잘만 DecaMax 500W 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [236/1156] AONE 시그니처 850W 80PLUS브론즈 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [237/1156] darkFlash 퍼펙트모스트 750W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [238/1156] DEEPCOOL PN850M 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [239/1156] CORSAIR RM1200x SHIFT 80PLUS골드 ATX3.0 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [240/1156] CORSAIR RM750x SHIFT 80PLUS골드 ATX3.0 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
#   📁 중간 저장 완료: 240개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 240/1156 (20.8%)
#
# [241/1156] 잘만 TeraMax II SE 750W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [242/1156] 마이크로닉스 ASTRO PLATINUM 850W 풀모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [243/1156] 리안리 EDGE 1000 80PLUS플래티넘 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [244/1156] 잘만 GigaMax III 850W 80PLUS브론즈 모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [245/1156] AONE STORM 700LF 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [246/1156] GIGABYTE UD850GM PG5 80PLUS골드 풀모듈러 ATX3.0 피씨디렉트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [247/1156] 3RSYS AK 750W 80PLUS브론즈 모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [248/1156] 마이크로닉스 Compact SFX 350W 80PLUS브론즈...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 350W...
#
# [249/1156] 잘만 MegaMax II 500W 80PLUS브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [250/1156] 리안리 EDGE 1300 80PLUS플래티넘 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1300W...
#
#   📁 중간 저장 완료: 250개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 250/1156 (21.6%)
#
# [251/1156] MSI MAG A1000GLS 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [252/1156] 시소닉 PRIME PLATINUM PX-2200 풀모듈러 ATX3...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 2200W...
#
# [253/1156] Segotep GM1000W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [254/1156] 3RSYS AK 1000W 80PLUS브론즈 모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [255/1156] MSI MAG A750GLS 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [256/1156] MSI MPG A1000GS II 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [257/1156] 맥스엘리트 MAXWELL DUKE 1300W 80PLUS플래티넘 풀모듈러 ATX3.1 화이...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1300W...
#
# [258/1156] 시소닉 PRIME TITANIUM TX-1300 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1300W...
#
# [259/1156] MSI MAG A500DN 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [260/1156] Segotep GM750W 80PLUS골드 풀모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
#   📁 중간 저장 완료: 260개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 260/1156 (22.5%)
#
# [261/1156] Segotep GM750W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [262/1156] CORSAIR HX1500i 80PLUS플래티넘 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1500W...
#
# [263/1156] 앱코 XPERT XP-600N...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [264/1156] 리안리 EDGE GOLD 1200 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
# [265/1156] 리안리 EDGE 850 80PLUS플래티넘 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [266/1156] 맥스엘리트 MAXWELL DUO 700W 80PLUS브론즈 PCIE5 플랫...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [267/1156] FSP HYPER K PRO 500W 브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [268/1156] 잘만 TeraMax II VIEW 1000W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [269/1156] AONE STORM 700W 80PLUS브론즈 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [270/1156] AONE 시그니처 1000W 80PLUS브론즈 풀모듈러 베이직 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
#   📁 중간 저장 완료: 270개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 270/1156 (23.4%)
#
# [271/1156] CORSAIR RM1000x SHIFT 80PLUS골드 ATX3.0 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [272/1156] AONE STORM 700LF...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [273/1156] 마이크로닉스 Compact SFX 300W 80PLUS브론즈...
#    - 제품 분류: M-ATX(SFX) 파워...
#    - 정격출력: 300W...
#
# [274/1156] 3RSYS AK 850W 80PLUS브론즈 모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [275/1156] SuperFlower SF-2000F14HP LEADEX PLATINUM...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 2000W...
#
# [276/1156] 잘만 GigaMax III 750W 80PLUS브론즈 모듈러 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [277/1156] GIGABYTE P650SS ICE 80PLUS실버 FDB ATX3.0 피씨디렉트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [278/1156] CORSAIR RM850e ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [279/1156] DEEPCOOL PN750M 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [280/1156] 리안리 EDGE 1300 80PLUS플래티넘 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1300W...
#
#   📁 중간 저장 완료: 280개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 280/1156 (24.2%)
#
# [281/1156] MSI MAG A650BNL 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 650W...
#
# [282/1156] darkFlash UPMOST 1250W 80PLUS골드 풀모듈러 ATX3.0 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1250W...
#
# [283/1156] CORSAIR RM1000x SHIFT 80PLUS골드 ATX3.0...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [284/1156] 앱코 코어맥스 CM-600B ETA브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [285/1156] FSP VITA GM 850W 80PLUS골드 ATX 3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [286/1156] 앱코 XPERT XP-500N...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 500W...
#
# [287/1156] 앱코 ULTIMATE GX850 80PLUS골드 풀모듈러 ATX3.0 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [288/1156] 앱코 SETTLER 하이브리드 PCIE5.1 STH-700B ETA BRONZE 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [289/1156] AONE STORM 1000W 80PLUS브론즈...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1000W...
#
# [290/1156] Antec GSK 750W 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
#   📁 중간 저장 완료: 290개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 290/1156 (25.1%)
#
# [291/1156] FSP VITA GM 750W 80PLUS골드 ATX 3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [292/1156] darkFlash UPMOST 1250W 80PLUS골드 풀모듈러 ATX3.0 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1250W...
#
# [293/1156] 쿨러마스터 MWE GOLD 850 V3 ATX3.1 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [294/1156] 잘만 GigaMax III 750W 80PLUS브론즈 모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [295/1156] MSI MAG A750GN 80PLUS골드 ATX 3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [296/1156] CORSAIR RM750e ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [297/1156] SuperFlower SF-850F14GE LEADEX III GOLD UP ATX3.1 ...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [298/1156] MSI MAG A850GL 화이트 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [299/1156] 맥스엘리트 MAXWELL COUNT 750W 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [300/1156] 잘만 MegaMax ET 700W 80PLUS스탠다드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
#   📁 중간 저장 완료: 300개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 300/1156 (26.0%)
#
# [301/1156] 쿨러마스터 X Mighty Platinum 2000W ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 2000W...
#
# [302/1156] 잘만 TeraMax II SE 850W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [303/1156] MSI MPG A1250GS II 80PLUS골드 풀모듈러 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1250W...
#
# [304/1156] FSP HYPER K PRO 600W 브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [305/1156] SuperFlower SF-850F14HT LEADEX TITANIUM...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [306/1156] FSP HYPER K PRO 700W 브론즈 ATX3.1...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [307/1156] AONE STORM 750W 80PLUS브론즈 벌크...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [308/1156] 잘만 ZM600W-XEII...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 600W...
#
# [309/1156] 시소닉 B12 BRONZE BM-850 모듈러...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 850W...
#
# [310/1156] 잘만 TeraMax II VIEW 1200W 80PLUS골드 풀모듈러 ATX3.1 블랙...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 1200W...
#
#   📁 중간 저장 완료: 310개 수집됨 (cpu_partial.csv)
#
#   📊 진행률: 310/1156 (26.8%)
#
# [311/1156] NEWZEN SKULL 750SM 모듈러 ATX3.1 80PLUS골드...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 750W...
#
# [312/1156] 앱코 SETTLER 하이브리드 PCIE5.1 STH-700B ETA BRONZE 화이트...
#    - 제품 분류: ATX 파워...
#    - 정격출력: 700W...
#
# [313/1156] Antec CSK PRO 1000W 80PLUS브론즈 230V EU 모듈러 ATX3.1...
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
import pandas as pd 
df = pd.read_csv('cpu.csv')

df
# Out:
#                                       제품명       가격                 제조사  \
# 0     AMD 라이젠7-5세대 7800X3D (라파엘) (멀티팩 정품)  453,640  AMD(제조사 웹사이트 바로가기)
# 1      인텔 코어 울트라5 시리즈2 245K (애로우레이크) (정품)  320,910   인텔(제조사 웹사이트 바로가기)
# 2      인텔 코어 울트라7 시리즈2 265K (애로우레이크) (정품)  449,530   인텔(제조사 웹사이트 바로가기)
# 3    AMD 라이젠5-6세대 9600 (그래니트 릿지) (멀티팩 정품)  275,930  AMD(제조사 웹사이트 바로가기)
# 4                AMD 라이젠5-5세대 7500F (라파엘)  185,470  AMD(제조사 웹사이트 바로가기)
# ..                                    ...      ...                 ...
# 547                   인텔 펜티엄 E5300 (울프데일)      940              인텔 펜티엄
# 548                 인텔 코어2듀오 E8500 (울프데일)    4,700            인텔 코어2듀오
# 549                 인텔 셀러론 G1630 (아이비브릿지)    2,200              인텔 셀러론
# 550                     인텔 펜티엄 E2200 (콘로)    5,400              인텔 펜티엄
# 551                   인텔 코어2듀오 E4500 (콘로)    8,010            인텔 코어2듀오
#
#                                                   상세정보  \
# 0    {'AMD CPU종류': '라이젠7-5세대', '코어 수': '8코어', '메모리 ...
# 1    {'인텔 CPU종류': '코어 울트라5(S2)', '코어 수': 'P6+E8코어',...
# 2    {'인텔 CPU종류': '코어 울트라7(S2)', '코어 수': 'P8+E12코어'...
# 3    {'AMD CPU종류': '라이젠5-6세대', '코어 수': '6코어', '메모리 ...
# 4    {'AMD CPU종류': '라이젠5-5세대', '코어 수': '6코어', '메모리 ...
# ..                                                 ...
# 547  {'인텔 CPU종류': '인텔(펜티엄)', '코어 수': '듀얼 코어', '내장그래...
# 548  {'인텔 CPU종류': '인텔(코어2듀오)', '코어 수': '듀얼 코어', '내장...
# 549  {'인텔 CPU종류': '인텔(셀러론)', '코어 수': '듀얼 코어', '메모리 ...
# 550  {'인텔 CPU종류': '인텔(펜티엄)', '코어 수': '듀얼 코어', '내장그래...
# 551  {'인텔 CPU종류': '인텔(코어2듀오)', '코어 수': '듀얼 코어', '내장...
#
#                                                    텍스트
# 0    AMD 라이젠7-5세대 7800X3D (라파엘) (멀티팩 정품) 453,640 AM...
# 1    인텔 코어 울트라5 시리즈2 245K (애로우레이크) (정품) 320,910 인텔(...
# 2    인텔 코어 울트라7 시리즈2 265K (애로우레이크) (정품) 449,530 인텔(...
# 3    AMD 라이젠5-6세대 9600 (그래니트 릿지) (멀티팩 정품) 275,930 A...
# 4    AMD 라이젠5-5세대 7500F (라파엘) 185,470 AMD(제조사 웹사이트 ...
# ..                                                 ...
# 547  인텔 펜티엄 E5300 (울프데일) 940 인텔 펜티엄 인텔 CPU종류 인텔(펜티엄...
# 548  인텔 코어2듀오 E8500 (울프데일) 4,700 인텔 코어2듀오 인텔 CPU종류 ...
# 549  인텔 셀러론 G1630 (아이비브릿지) 2,200 인텔 셀러론 인텔 CPU종류 인텔...
# 550  인텔 펜티엄 E2200 (콘로) 5,400 인텔 펜티엄 인텔 CPU종류 인텔(펜티엄...
# 551  인텔 코어2듀오 E4500 (콘로) 8,010 인텔 코어2듀오 인텔 CPU종류 인텔...
#
# [552 rows x 5 columns]

# %%
import pandas as pd
import ast

df = pd.read_csv('sdd_data_all.csv', encoding='utf-8-sig')

def create_embedding_text(row):
    specs = ast.literal_eval(row['상세정보'])
    spec_text = " ".join([f"{k} {v}" for k, v in specs.items()])
    return f"{row['제품명']} {row['가격']} {row['제조사']} {spec_text}"

df['텍스트'] = df.apply(create_embedding_text, axis=1)
df.to_csv('sdd.csv', index=False, encoding='utf-8-sig')

# %%
import pandas as pd 

df = pd.read_csv(r'C:\Users\PCN\Desktop\pcn\가공데이터\ssd.csv')
df = df.drop('상세정보',axis=1)
df.to_csv(r'C:\Users\PCN\Desktop\pcn\가공데이터\ssd.csv')

# %%
df = df.drop('상세정보',axis=1)
df
# Out:
#                                       제품명       가격                 제조사  \
# 0     AMD 라이젠7-5세대 7800X3D (라파엘) (멀티팩 정품)  453,640  AMD(제조사 웹사이트 바로가기)
# 1      인텔 코어 울트라5 시리즈2 245K (애로우레이크) (정품)  320,910   인텔(제조사 웹사이트 바로가기)
# 2      인텔 코어 울트라7 시리즈2 265K (애로우레이크) (정품)  449,530   인텔(제조사 웹사이트 바로가기)
# 3    AMD 라이젠5-6세대 9600 (그래니트 릿지) (멀티팩 정품)  275,930  AMD(제조사 웹사이트 바로가기)
# 4                AMD 라이젠5-5세대 7500F (라파엘)  185,470  AMD(제조사 웹사이트 바로가기)
# ..                                    ...      ...                 ...
# 547                   인텔 펜티엄 E5300 (울프데일)      940              인텔 펜티엄
# 548                 인텔 코어2듀오 E8500 (울프데일)    4,700            인텔 코어2듀오
# 549                 인텔 셀러론 G1630 (아이비브릿지)    2,200              인텔 셀러론
# 550                     인텔 펜티엄 E2200 (콘로)    5,400              인텔 펜티엄
# 551                   인텔 코어2듀오 E4500 (콘로)    8,010            인텔 코어2듀오
#
#                                                    텍스트
# 0    AMD 라이젠7-5세대 7800X3D (라파엘) (멀티팩 정품) 453,640 AM...
# 1    인텔 코어 울트라5 시리즈2 245K (애로우레이크) (정품) 320,910 인텔(...
# 2    인텔 코어 울트라7 시리즈2 265K (애로우레이크) (정품) 449,530 인텔(...
# 3    AMD 라이젠5-6세대 9600 (그래니트 릿지) (멀티팩 정품) 275,930 A...
# 4    AMD 라이젠5-5세대 7500F (라파엘) 185,470 AMD(제조사 웹사이트 ...
# ..                                                 ...
# 547  인텔 펜티엄 E5300 (울프데일) 940 인텔 펜티엄 인텔 CPU종류 인텔(펜티엄...
# 548  인텔 코어2듀오 E8500 (울프데일) 4,700 인텔 코어2듀오 인텔 CPU종류 ...
# 549  인텔 셀러론 G1630 (아이비브릿지) 2,200 인텔 셀러론 인텔 CPU종류 인텔...
# 550  인텔 펜티엄 E2200 (콘로) 5,400 인텔 펜티엄 인텔 CPU종류 인텔(펜티엄...
# 551  인텔 코어2듀오 E4500 (콘로) 8,010 인텔 코어2듀오 인텔 CPU종류 인텔...
#
# [552 rows x 4 columns]
